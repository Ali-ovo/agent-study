# %%
from langchain_openai import OpenAIEmbeddings
embeddings_model = OpenAIEmbeddings()
embeddings = embeddings_model.embed_documents(
    [
        "Hi there!",
        "Oh, hello!",
        "What's your name?",
        "My friends call me World",
        "Hello World!"
    ]
)
len(embeddings), len(embeddings[0])
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[1], line 2
#       1 from langchain_openai import OpenAIEmbeddings
# ----> 2 embeddings_model = OpenAIEmbeddings()
#       3 embeddings = embeddings_model.embed_documents(
#       4     [
#       5         "Hi there!",
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/local-code/.venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:452, in OpenAIEmbeddings.validate_environment(self)
#     447         self.http_async_client = httpx.AsyncClient(proxy=self.openai_proxy)
#     448     async_specific = {
#     449         "http_client": self.http_async_client,
#     450         "api_key": async_api_key_value,
#     451     }
# --> 452     self.async_client = openai.AsyncOpenAI(
#     453         **client_params,
#     454         **async_specific,  # type: ignore[arg-type]
#     455     ).embeddings
#     456 return self
#
# File ~/Desktop/local-code/.venv/lib/python3.13/site-packages/openai/_client.py:700, in AsyncOpenAI.__init__(self, api_key, admin_api_key, workload_identity, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation, _enforce_credentials)
#     691 self.admin_api_key = admin_api_key
#     693 if (
#     694     _enforce_credentials
#     695     and not self.api_key
#    (...)    698     and self.admin_api_key is None
#     699 ):
# --> 700     raise OpenAIError(
#     701         "Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable."
#     702     )
#     704 if organization is None:
#     705     organization = os.environ.get("OPENAI_ORG_ID")
#
# OpenAIError: Missing credentials. Please pass an `api_key`, `workload_identity`, `admin_api_key`, or set the `OPENAI_API_KEY` or `OPENAI_ADMIN_KEY` environment variable.
